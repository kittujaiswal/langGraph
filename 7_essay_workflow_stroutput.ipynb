# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict, Annotated
from pydantic import BaseModel, Field
import operator

# %%
model = ChatOpenAI(model='gpt-5-nano')

# %%
class EvaluationSchema(BaseModel):
    feedback: str = Field(description='Detailed feedback for the essay')
    score: int = Field(description='Score out of 10', ge=0, le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %%
essay = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.
India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.
One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.
However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.
Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.
To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.
India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.
In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {essay}'
structured_model.invoke(prompt).feedback
# Out:
# 'Strengths:\n- Clear purpose and well-structured argument. The essay progresses logically from India’s strengths to challenges and policy recommendations.\n- Formal, professional tone with appropriate domain vocabulary (predictive analytics, multi-stakeholder, interoperability, demographics).\n- Effective use of examples across sectors (agriculture, healthcare, education, governance) to illustrate AI’s potential, and a balanced treatment of risks and opportunities.\n\nAreas for improvement:\n- Some sentences are lengthy; breaking them up would improve readability (e.g., the opening paragraph contains a long sentence that could be split).\n- A few phrases feel conventional; tighten wording to increase impact (consider replacing certain clichés with more precise language).\n- Strengthen the introduction with a clear thesis and a brief roadmap outlining the essay’s structure.\n- Ground factual claims with sources or caveats. If numerical figures are used (e.g., “over 5 million STEM graduates annually”), consider citing sources or labeling them as indicative.\n- Improve rhythm and coherence by varying sentence length and structure to avoid repetition and enhance readability.\n\nSuggestions for revision:\n- Break complex sentences and insert a brief roadmap in the introduction (e.g., what will be covered in strengths, challenges, and recommendations).\n- Add a couple of concrete data points with citations or clearly mark them as illustrative.\n- Tighten phrasing and replace clichés with sharper, more precise language.\n- Conclude with explicit policy recommendations or action steps to strengthen the practical takeaway for readers.'

# %%
class UPSCState(TypedDict):

    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %%
def evaluate_language(state: UPSCState):

    prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'language_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_analysis(state: UPSCState):

    prompt = f'Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'analysis_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_thought(state: UPSCState):

    prompt = f'Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'clarity_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def final_evaluation(state: UPSCState):

    # summary feedback
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state["language_feedback"]} \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of thought feedback - {state["clarity_feedback"]}'
    overall_feedback = model.invoke(prompt).content

    # avg calculate
    avg_score = sum(state['individual_scores'])/len(state['individual_scores'])

    return {'overall_feedback': overall_feedback, 'avg_score': avg_score}

# %%
graph = StateGraph(UPSCState)

graph.add_node('evaluate_language', evaluate_language)
graph.add_node('evaluate_analysis', evaluate_analysis)
graph.add_node('evaluate_thought', evaluate_thought)
graph.add_node('final_evaluation', final_evaluation)
# edges
graph.add_edge(START, 'evaluate_language')
graph.add_edge(START, 'evaluate_analysis')
graph.add_edge(START, 'evaluate_thought')
graph.add_edge('evaluate_language', 'final_evaluation')
graph.add_edge('evaluate_analysis', 'final_evaluation')
graph.add_edge('evaluate_thought', 'final_evaluation')
graph.add_edge('final_evaluation', END)
workflow = graph.compile()

# %%
workflow

# %%
essay2 = """India and AI Time

Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.

India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.

In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.

But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.

One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.

India must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.

If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.

So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India"."""

# %%
intial_state = {
    'essay': essay2
}

workflow.invoke(intial_state)
# Out:
# {'essay': 'India and AI Time\n\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\n\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\n\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\n\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\n\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\n\nIndia must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\n\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\n\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".',
#  'language_feedback': 'Overall verdict: The essay has a clear topic and a straightforward structure, but the language quality is limited by frequent grammar errors and awkward phrasing. Strengths include a simple, accessible idea and concrete examples (farm, health, school, transport) plus a hopeful, inclusive message. Weaknesses and concrete fixes follow.\n\nStrengths\n- Clear topic and basic organization (introduction, benefits, challenges, conclusion).\n- Uses tangible examples to illustrate AI’s potential in different sectors.\n- Positive emphasis on inclusive benefits and collaboration across society.\n\nAreas for improvement\n- Grammar and sentence structure: fix subject–verb agreement and tense consistency. Examples: “Now world change very fast” → “The world is changing very fast.” “India also want become big” → “India also wants to become big.”\n- Word choice and spelling: correct terms like “engine-ear” (likely “engineer”), “peoples” → “people,” and standardize phrases (e.g., “In farm” → “In farming” or “In agriculture”).\n- Articles and plurals: use proper articles (a/an/the) and plural forms consistently.\n- Punctuation and capitalization: use periods to end sentences; capitalize proper nouns (India, AI, Government) consistently.\n- Cohesion and clarity: some sentences read as fragments or choppy ideas; use transitions and keep each paragraph focused on a single idea. Some phrases are vague (e.g., “AI to find bad people” could be clarified to “AI to detect fraud or misuse in public services”).\n- Accuracy and specificity: when describing policy ideas, suggest concrete examples (data protection rules, access for rural areas, retraining programs) to strengthen argument.\n\nSuggestions for improvement\n- Define AI once: “Artificial Intelligence (AI)” and then use AI throughout.\n- Revise key sentences for grammar and flow; consider rewriting sections into tighter, parallel sentences (e.g., benefits in farming, health, education, and governance).\n- Add smooth transitions between paragraphs and a stronger concluding statement that restates the thesis about inclusive growth.\n- Expand with concrete policy proposals to address the challenges (access to devices/internet, job displacement, privacy protections).\n\nIf you rewrite the piece with these fixes, the message will be much clearer while preserving the original hopeful perspective.',
#  'analysis_feedback': 'Strengths: The essay engages with a timely topic and identifies concrete sectors (farming, health, education, governance) where AI could impact India. It acknowledges both opportunities and risks, including inclusion, privacy, and the digital divide, and it advocates for inclusive growth. Weaknesses: The analysis remains superficial and largely descriptive, with few specifics, data, or evidence to support claims. It lacks depth in policy analysis: no concrete policy proposals, governance mechanisms, or implementation steps. There is little discussion of trade-offs, potential mitigation strategies (e.g., skilling, re-skilling, public–private partnerships, accountability), or how to measure impact. The argument would benefit from data, case studies, or comparisons with other countries. Language is generally understandable but grammar and clarity could be improved. Suggestions: add India-specific data or case examples; outline a concrete policy framework (data protection, digital infrastructure, rural connectivity, skilling programs, safety nets); discuss governance mechanisms (impact assessments, AI ethics guidelines, regulatory sandboxes, data localization where appropriate); propose steps for inclusive adoption and risk mitigation (privacy, bias, explainability); compare with international approaches to illustrate options; strengthen the structure with a clearer thesis and sub-points. Overall, a solid starting point but needs deeper analysis, evidence, and actionable recommendations to reach a higher score.',
#  'clarity_feedback': 'Overall, the essay communicates a clear central idea that AI presents both opportunities and risks for India and argues for inclusive benefits. Strengths: it identifies concrete sectors (farming, health, education, governance) and recognizes issues like the digital divide, potential job displacement, and privacy. Areas for improvement: organization and flow could be stronger; transitions between ideas are abrupt; language and grammar are inconsistent (for example engine-ear, In farm). Suggestions: - reorganize into a clear intro, body, and conclusion; start with a thesis, followed by supporting paragraphs; - make each paragraph focus on one main idea and use topic sentences; - improve coherence with transitions such as additionally or however; - fix grammar and word choices (engineer, villagers, phones); - add more specifics or data to back claims (data privacy rules, digital inclusion programs); - avoid generalities or hyperbole and consider addressing counterarguments; - end with a stronger, actionable conclusion. In short, the essay has promising ideas but would benefit from clearer structure and more precise writing to maximize clarity.',
#  'overall_feedback': 'Summary feedback\n\nOverall impression\n- The essay has a clear topic and straightforward structure, but language quality limits its impact. It shows promise with an inclusive, hopeful message and concrete sector examples, but it needs deeper analysis and more precise writing.\n\nWhat works (strengths)\n- Clear topic and basic organization (intro, benefits, challenges, conclusion).\n- Uses tangible sectors (farming, health, education, governance/transport) to illustrate AI’s potential.\n- Positive emphasis on inclusive benefits and collaboration across society.\n- Acknowledges opportunities and risks (inclusion, privacy, digital divide).\n\nKey issues (areas for improvement)\n- Language and grammar: fix subject–verb agreement and tense consistency; standardize terms (engineer, people, farming/agriculture); ensure proper articles and plurals; fix fragments and choppy sentences.\n- Clarity and cohesion: some phrases are vague or awkward; improve transitions between ideas; ensure each paragraph centers on a single idea.\n- Precision and specificity: avoid vague claims (e.g., “AI to find bad people”) and replace with concrete examples (e.g., “AI to detect fraud or misuse in public services”).\n- Policy depth: add concrete policy proposals, governance mechanisms, and implementation steps (data protection, rural access, retraining, safety nets). Include data, case studies, or comparisons to strengthen arguments.\n- Structure: present a clear thesis upfront; use topic sentences; improve transitions; end with a stronger, actionable conclusion that reiterates inclusive growth.\n- Definition and consistency: define AI once (Artificial Intelligence, AI) and maintain consistency throughout.\n\nConcrete fixes to consider (short checklist)\n- Define AI at the outset and use AI consistently.\n- Correct recurring errors (e.g., engine-ear → engineer; In farm → In farming; villagers/phones, India, AI, Government capitalization).\n- Tighten sentences for grammar and flow; use parallel structure in sections (benefits in farming, health, education, governance).\n- Add transitions and keep paragraphs focused on one main idea.\n- Replace vague phrases with specific examples and data points.\n- Propose concrete policies: data protection rules, rural connectivity, skilling/re-skilling programs, safety nets, regulatory sandboxes, data localization where appropriate.\n- Include India-specific data, case studies, or comparative examples from other countries.\n- End with a strong, actionable conclusion restating the thesis on inclusive growth.\n\nRecommended rewrite plan (brief)\n- Start with a concise thesis: AI can drive inclusive growth in India while presenting governance and equity challenges.\n- Structure body into four tight sections: benefits in farming, health, education, governance, each with 1–2 concrete examples and a policy angle.\n- Add a dedicated challenges section with data privacy, digital divide, and job displacement, followed by concrete mitigation strategies.\n- Conclude with a clear policy agenda and a restatement of the inclusive growth message.\n\nIf you rewrite with these fixes, the piece will be clearer, more persuasive, and better grounded in policy and data while preserving the original hopeful perspective.',
#  'individual_scores': [5, 4, 6],
#  'avg_score': 5.0}
